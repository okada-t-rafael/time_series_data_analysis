# %% [markdown]
# <a href="https://colab.research.google.com/github/okada-t-rafael/time_series_data_analysis/blob/master/33_TS_Pandas_Rolling_and_Expanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2234d422-e406-4484-84b3-386ff40c3728" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2234d422-e406-4484-84b3-386ff40c3728">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving starbucks.csv to starbucks.csv
# ...

# %%
df = pd.read_csv('starbucks.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df['Close'].plot(figsize=(12, 5))

# %%
df.rolling(window=7).mean()
# Out:
#                 Close        Volume
# Date
# 2015-01-02        NaN           NaN
# 2015-01-05        NaN           NaN
# 2015-01-06        NaN           NaN
# 2015-01-07        NaN           NaN
# 2015-01-08        NaN           NaN
# ...               ...           ...
# 2018-12-24  63.270000  1.528625e+07
# 2018-12-26  62.947143  1.525942e+07
# 2018-12-27  62.765714  1.471157e+07
# 2018-12-28  62.547143  1.430995e+07
# 2018-12-31  62.595714  1.335281e+07
#
# [1006 rows x 2 columns]

# %%
df['Close'].plot(figsize=(12,5))
df.rolling(window=20).mean()['Close'].plot()
df.rolling(window=140).mean()['Close'].plot()

# %%
df['Close: 30 Day Mean'] = df['Close'].rolling(window=30).mean()
df.tail()
# Out:
#             Close    Volume  Close: 30 Day Mean
# Date
# 2018-12-24  60.56   6323252           65.963703
# 2018-12-26  63.08  16646238           65.791913
# 2018-12-27  63.20  11308081           65.647000
# 2018-12-28  63.39   7712127           65.525000
# 2018-12-31  64.40   7690183           65.437000

# %%
df[['Close', 'Close: 30 Day Mean']].plot(figsize=(12, 5))

# %%
df['Close'].expanding().mean().plot(figsize=(12, 5))
