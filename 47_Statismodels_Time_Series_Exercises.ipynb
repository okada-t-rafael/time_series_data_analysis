# %% [markdown]
# <a href="https://colab.research.google.com/github/okada-t-rafael/time_series_data_analysis/blob/master/47_Statismodels_Time_Series_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Statsmodels Time Series Excercises
# For this set of exercises we're using data from the Federal Reserve Economic Database (FRED) concerning the Industrial Production Index for Electricity and Gas Utilities from January 1970 to December 1989.
#
# Data source: https://fred.stlouisfed.org/series/IPG2211A2N
#
# <div class="alert alert-danger" style="margin: 10px"><strong>IMPORTANT NOTE!</strong> Make sure you don't run the cells directly above the example output shown, <br>otherwise you will end up writing over the example output!</div>

# %%
# RUN THIS CELL
import pandas as pd
import numpy as np
# %matplotlib inline

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-de8a6fec-932b-4e16-9e29-9f5a7c51eae1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de8a6fec-932b-4e16-9e29-9f5a7c51eae1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving EnergyProduction.csv to EnergyProduction.csv
# {'EnergyProduction.csv': b'DATE,EnergyIndex\n1970-01-01,43.0869\n1970-02-01,42.5577\n1970-03-01,41.6215\n1970-04-01,40.1982\n1970-05-01,39.9321\n1970-06-01,41.1847\n1970-07-01,43.2230\n1970-08-01,44.8138\n1970-09-01,43.6007\n1970-10-01,40.5467\n1970-11-01,40.9385\n1970-12-01,42.1117\n1971-01-01,44.9517\n1971-02-01,44.3696\n1971-03-01,42.7548\n1971-04-01,41.4234\n1971-05-01,40.8295\n1971-06-01,43.5488\n1971-07-01,45.1876\n1971-08-01,46.1091\n1971-09-01,45.5050\n1971-10-01,43.9496\n1971-11-01,44.0030\n1971-12-01,45.6054\n1972-01-01,48.8392\n1972-02-01,50.0191\n1972-03-01,47.8421\n1972-04-01,44.5127\n1972-05-01,42.1061\n1972-06-01,43.8217\n1972-07-01,45.3964\n1972-08-01,47.9891\n1972-09-01,46.8293\n1972-10-01,44.6882\n1972-11-01,47.1979\n1972-12-01,52.1760\n1973-01-01,55.9342\n1973-02-01,53.9974\n1973-03-01,50.5102\n1973-04-01,46.8192\n1973-05-01,44.9288\n1973-06-01,47.4589\n1973-07-01,49.3168\n1973-08-01,51.0910\n1973-09-01,50.0826\n1973-10-01,47.0794\n1973-11-01,47.8829\n1973-12-01,49.7968\n1974-01-01,53.8211\n1974-02-01,51.6562\n1974-03-01,49.7984\n1974-04-01,46.8319\n1974-05-01,45.4161\n1974-06-01,47.1087\n1974-07-01,50.7056\n1974-08-01,51.7371\n1974-09-01,48.6743\n1974-10-01,47.1173\n1974-11-01,47.7516\n1974-12-01,52.9378\n1975-01-01,55.6989\n1975-02-01,54.4115\n1975-03-01,52.1395\n1975-04-01,49.3369\n1975-05-01,46.1066\n1975-06-01,47.3769\n1975-07-01,50.5251\n1975-08-01,52.2585\n1975-09-01,49.4320\n1975-10-01,46.7476\n1975-11-01,47.7981\n1975-12-01,54.4112\n1976-01-01,60.6120\n1976-02-01,56.9337\n1976-03-01,52.9187\n1976-04-01,48.7185\n1976-05-01,46.6811\n1976-06-01,49.2486\n1976-07-01,52.0220\n1976-08-01,53.3791\n1976-09-01,51.1014\n1976-10-01,49.1373\n1976-11-01,53.2579\n1976-12-01,60.8207\n1977-01-01,66.1065\n1977-02-01,61.3553\n1977-03-01,54.9875\n1977-04-01,50.5114\n1977-05-01,49.3163\n1977-06-01,52.3147\n1977-07-01,55.7601\n1977-08-01,55.9290\n1977-09-01,53.2255\n1977-10-01,50.7423\n1977-11-01,51.8983\n1977-12-01,59.5842\n1978-01-01,65.4681\n1978-02-01,64.4632\n1978-03-01,58.7322\n1978-04-01,51.4137\n1978-05-01,49.9912\n1978-06-01,53.1982\n1978-07-01,55.5156\n1978-08-01,57.5132\n1978-09-01,55.0594\n1978-10-01,52.1993\n1978-11-01,54.0540\n1978-12-01,60.7576\n1979-01-01,68.7075\n1979-02-01,68.1212\n1979-03-01,61.3740\n1979-04-01,55.2722\n1979-05-01,51.4048\n1979-06-01,53.2473\n1979-07-01,55.4418\n1979-08-01,57.6476\n1979-09-01,54.2322\n1979-10-01,52.7558\n1979-11-01,54.6456\n1979-12-01,60.0874\n1980-01-01,65.3810\n1980-02-01,64.7721\n1980-03-01,60.8807\n1980-04-01,53.1114\n1980-05-01,49.7992\n1980-06-01,52.4268\n1980-07-01,58.5254\n1980-08-01,60.4105\n1980-09-01,57.7380\n1980-10-01,54.7637\n1980-11-01,56.4616\n1980-12-01,63.4413\n1981-01-01,69.2715\n1981-02-01,63.6341\n1981-03-01,60.1027\n1981-04-01,54.1446\n1981-05-01,52.2484\n1981-06-01,56.4915\n1981-07-01,60.6220\n1981-08-01,60.6506\n1981-09-01,56.3729\n1981-10-01,54.6841\n1981-11-01,55.7249\n1981-12-01,63.4345\n1982-01-01,70.6727\n1982-02-01,64.2728\n1982-03-01,59.7759\n1982-04-01,54.1090\n1982-05-01,49.8577\n1982-06-01,52.7065\n1982-07-01,56.6437\n1982-08-01,57.1923\n1982-09-01,54.0000\n1982-10-01,51.7022\n1982-11-01,54.0655\n1982-12-01,58.7664\n1983-01-01,65.9628\n1983-02-01,59.1620\n1983-03-01,57.3140\n1983-04-01,52.9718\n1983-05-01,49.1707\n1983-06-01,51.7103\n1983-07-01,57.9314\n1983-08-01,61.5880\n1983-09-01,57.8078\n1983-10-01,53.7753\n1983-11-01,55.7980\n1983-12-01,65.6301\n1984-01-01,73.2688\n1984-02-01,66.2545\n1984-03-01,63.2801\n1984-04-01,57.4501\n1984-05-01,55.1499\n1984-06-01,57.9273\n1984-07-01,60.6775\n1984-08-01,62.3596\n1984-09-01,58.0827\n1984-10-01,54.7212\n1984-11-01,57.1673\n1984-12-01,63.3492\n1985-01-01,72.6803\n1985-02-01,70.8479\n1985-03-01,62.6166\n1985-04-01,57.6106\n1985-05-01,55.4467\n1985-06-01,58.2228\n1985-07-01,62.7591\n1985-08-01,63.3921\n1985-09-01,60.7507\n1985-10-01,56.4553\n1985-11-01,58.1385\n1985-12-01,68.8758\n1986-01-01,73.4956\n1986-02-01,68.1637\n1986-03-01,62.3923\n1986-04-01,57.1915\n1986-05-01,55.9599\n1986-06-01,60.0 ...

# %%
df = pd.read_csv('EnergyProduction.csv',index_col=0,parse_dates=True)
df.head()
# Out:
#             EnergyIndex
# DATE
# 1970-01-01      43.0869
# 1970-02-01      42.5577
# 1970-03-01      41.6215
# 1970-04-01      40.1982
# 1970-05-01      39.9321

# %% [markdown]
# ### 1. Assign a frequency of 'MS' to the DatetimeIndex.

# %%
# CODE HERE

df.index.freq = 'MS'
df.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '1989-03-01', '1989-04-01', '1989-05-01', '1989-06-01',
#                '1989-07-01', '1989-08-01', '1989-09-01', '1989-10-01',
#                '1989-11-01', '1989-12-01'],
#               dtype='datetime64[ns]', name='DATE', length=240, freq='MS')

# %%
# DON'T WRITE HERE
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '1989-03-01', '1989-04-01', '1989-05-01', '1989-06-01',
#                '1989-07-01', '1989-08-01', '1989-09-01', '1989-10-01',
#                '1989-11-01', '1989-12-01'],
#               dtype='datetime64[ns]', name='DATE', length=240, freq='MS')

# %% [markdown]
# ### 2. Plot the dataset.

# %%
# CODE HERE
df['EnergyIndex'].plot(figsize=(12, 6))

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 3. Add a column that shows a 12-month Simple Moving Average (SMA).<br>&nbsp;&nbsp;&nbsp;&nbsp;Plot the result.

# %%
df['SMA12'] = df['EnergyIndex'].rolling(window=12).mean()
df.plot(figsize=(12, 6))

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 4. Add a column that shows an Exponentially Weighted Moving Average (EWMA) with a span of 12 using the statsmodels <tt>SimpleExpSmoothing</tt> function. Plot the result.

# %%
# DON'T FORGET TO PERFORM THE IMPORT!
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

span = 12
alpha = 2 / (span + 1)

model = SimpleExpSmoothing(df['EnergyIndex'])
fitted_model = model.fit(smoothing_level=alpha, optimized=False)
df['SES12'] = fitted_model.fittedvalues.shift(-1)
df.plot(figsize=(12, 6))

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 5. Add a column to the DataFrame that shows a Holt-Winters fitted model using Triple Exponential Smoothing with multiplicative models. Plot the result.

# %%
# DON'T FORGET TO PERFORM THE IMPORT!
from statsmodels.tsa.holtwinters import ExponentialSmoothing

model = ExponentialSmoothing(df['EnergyIndex'], trend='mul', seasonal='mul', seasonal_periods=12)
fitted_model = model.fit()
df['TESmul12'] = fitted_model.fittedvalues
df.plot(figsize=(12, 6))
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### OPTIONAL: Plot the same  as above, but for only the first two years.

# %%
df.iloc[:24].plot(figsize=(12, 6))

# %%
# DON'T WRITE HERE

# %% [markdown]
# ## Great job!
