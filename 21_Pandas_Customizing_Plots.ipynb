# %% [markdown]
# <a href="https://colab.research.google.com/github/okada-t-rafael/time_series_data_analysis/blob/master/21_Pandas_Customizing_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d6c9caed-7fa0-481e-98da-3d4ce059164c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6c9caed-7fa0-481e-98da-3d4ce059164c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving df2.csv to df2.csv
# ...

# %%
df2 = pd.read_csv('df2.csv')
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df2['c'].plot.line(figsize=(10,5), ls=':', c='red', lw=3)

# %%
title = 'MY PLOT TITLE'
xlabel = 'My X Data'
ylabel = 'My Y Data'

# %%
ax = df2['c'].plot.line(figsize=(6, 4), ls=':', c='red', lw=3, title=title)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'My Y Data'), Text(0.5, 0, 'My X Data')]

# %%
ax = df2.plot()
ax.legend(loc=0, bbox_to_anchor=(1.0, 1.0))
