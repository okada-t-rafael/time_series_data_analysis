# %% [markdown]
# <a href="https://colab.research.google.com/github/okada-t-rafael/time_series_data_analysis/blob/master/41_Statsmodels_ETS_Decomposition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d96d6b03-3ffc-4a2c-bf79-55a66f526b0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d96d6b03-3ffc-4a2c-bf79-55a66f526b0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving airline_passengers.csv to airline_passengers.csv
# ...

# %%
airline = pd.read_csv('airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
airline = airline.dropna()

# %%
airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
airline.plot(figsize=(12, 5))

# %%
result = seasonal_decompose(airline['Thousands of Passengers'], model='multiplicative')

# %%
result.plot()
trend = result.trend
seasonal = result.seasonal
residual = result.resid

# %%
trend.plot(figsize=(12, 5))

# %%
seasonal.plot(figsize=(12, 5))

# %%
residual.plot(figsize=(12, 5))
