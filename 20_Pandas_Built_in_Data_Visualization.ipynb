# %% [markdown]
# <a href="https://colab.research.google.com/github/okada-t-rafael/time_series_data_analysis/blob/master/20_Pandas_Built_in_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b1ed958a-e3d9-45f2-b30f-1784d05b4e72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1ed958a-e3d9-45f2-b30f-1784d05b4e72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving df1.csv to df1.csv
# Saving df2.csv to df2.csv
# Saving df3.csv to df3.csv

# %%
df1 = pd.read_csv('df1.csv', index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(bins=20, edgecolor='k').autoscale(enable=True, axis='both', tight=True)

# %%
df1['A'].plot.hist(grid=True)

# %%
df2.plot.barh(stacked=True)

# %%
df2.plot.line(y=['a', 'b', 'c'], figsize=(10, 4), lw=4)

# %%
df2.plot.area(stacked=False, alpha=0.4)

# %%
df1.plot.scatter(x='A', y='B', c='D', cmap='coolwarm')

# %%
df1.plot.scatter(x='A', y='B', s=df1['C'] ** 2 * 50, alpha=0.3)

# %%
df2.plot.box()

# %%
df2['a'].plot.kde()

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.head()
# Out:
#           a         b
# 0  1.848882  0.447267
# 1  0.010809  0.441268
# 2  0.501554 -0.696279
# 3 -0.928581  0.360362
# 4  1.361628  0.093862

# %%
df.plot.scatter(x='a', y='b')

# %%
df.plot.hexbin(x='a', y='b', gridsize=25, cmap='coolwarm')
